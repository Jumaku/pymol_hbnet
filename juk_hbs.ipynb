# %% [markdown]
# # Init

# %%
import os
import sys
import pandas as pd
import subprocess
import contextlib
from datetime import datetime
import numpy as np
from pymol import cmd, stored
import platform
import pathlib
import xmlrpc.client as xmlrpclib
# cmd = xmlrpclib.ServerProxy('http://localhost:9123')

# %% [markdown]
# ## Error Classes

# %%
class SubprocessError(Exception):
    """Raised when subprocess execution fails."""
    def __init__(self, message, output=None):
        self.message = message
        self.output = output
        super().__init__(self.message)

class InvalidSelectionError(Exception):
    """Raised when subprocess execution fails."""
    def __init__(self, message, output=None):
        self.message = message
        self.output = output
        super().__init__(self.message)

class PymolObjectListError(Exception):
    """Raised when a group for a specific pdbID is already present in Pymol Session."""
    def __init__(self, message, output=None):
        self.message = message
        self.output = output
        super().__init__(self.message)

class DirectoryStructureError(Exception):
    """Raised when the directory structure does not match the expected structure."""
    def __init__(self, missing_items):
        self.missing_items = missing_items
        self.message = f"The following items are missing: {', '.join(missing_items)}"
        super().__init__(self.message)

class PipelineError(Exception):
    """Raised when subsequent steps in the program are skipped. I.E hbnet is executed before hbsearch."""
    def __init__(self, message, output=None):
        self.message = message
        self.output = output
        super().__init__(self.message)

class PDBError(Exception):
    """Base class for PDB related errors."""
    pass

class PDBFileNotFoundError(PDBError):
    """Raised when the PDB file does not exist."""
    def __init__(self, pdb_file):
        self.pdb_file = pdb_file
        self.message = f'ERROR: {pdb_file} does not exist!'
        super().__init__(self.message)

class InvalidPDBIDError(PDBError):
    """Raised when an invalid PDB ID is provided."""
    def __init__(self, pdb_id):
        self.pdb_id = pdb_id
        self.message = f'ERROR: {pdb_id} is not a valid PDB-ID!'
        super().__init__(self.message)

class PDBFetchError(PDBError):
    """Raised when fetching a PDB ID fails."""
    def __init__(self, pdb_id):
        self.pdb_id = pdb_id
        self.message = f'ERROR-fetch: unable to fetch "{pdb_id}"'
        super().__init__(self.message)

# %% [markdown]
# # Info Handling

# %%
class DictionaryManager:
    '''This class serves the purpose to share information saved in the my_dict dictionary across the implemented functions'''
    def __init__(self):
        self.my_dict = {}

    def update_dict(self, dct):
        """
        Update the dictionary with new dictionary.
        """
        self.my_dict = dct
        
    def get_dict(self):
        """
        Print the contents of the dictionary.
        """
        return self.my_dict

# %% [markdown]
# ## Hbsearch related

# %%
def get_date():
    '''Returns the current date and time'''
    return datetime.now().strftime("%Y-%m-%d-%H:%M:%S")

# %%
def form4cmd(pdbID, x):
    '''
    Part of lambda function to format dataframe to Pymol compatible form:
    from "A:183:LEU:O" to "/2akr//A/LEU`183/O"
    :param pdbstr: pdb code of handled structure
    :param x: entry within dataframe
    '''
    chain, resID, amiaci, atom = x.split(':')
    ret = f'/{pdbID}//{chain}/{resID}/{atom}'
    return ret

# %%
def formID(pdbID, x):
    '''
    Part of lambda function to form distance ID for pymol object naming:
    from "/2akr//A/LEU`183/O" to "A183O"
    :param pdbstr: pdb code of handled structure
    :param x: entry within dataframe
    '''
    pdbstr, chain, resID, atom  = filter(None, x.split('/'))

    ret = f"{chain}{resID}{atom}" 

    return ret

# %%
def check_directory(script_path):
    '''
    Function to validate the directory and file structure for a project based on the provided `script_path`.
    The structure differs depending on the operating system (macOS, Linux, Windows) or general base files.
    
    :param script_path: The path to the root directory of the project where the structure will be checked.
    '''
    
    # Expected directory and file structure
    # Dictionary where keys represent different operating systems (Darwin for macOS, Linux, Windows) 
    # and the value is a list of expected files or executables for that platform.
    # The empty string "" represents the base directory where general files are expected.
    expected_structure = {
        "Darwin": ["get-water-cluster", "hb-network", "hb-search"],
        "Linux": ["get-water-cluster", "hb-network", "hb-search"],
        "Windows": ["get-water-cluster.exe", "hb-network.exe", "hb-search.exe"],
        "": ["hb-define.txt", "hb_results", "pdb_files",  "hbscript.py", "hb-search_script.ipynb", "period-table-info.txt", "README.md"]
    }
    
    # List to store missing files or directories
    missing_items = []
    
    # Loop through the expected directory structure
    for directory, expected_files in expected_structure.items():
        # Construct the full path to the directory
        dir_path = os.path.join(script_path, directory)
        
        # If the directory is not the base directory (represented by ""),
        # check whether the directory exists.
        if directory and not os.path.isdir(dir_path):
            # If the directory does not exist, record it as missing
            missing_items.append(f"Missing directory: {dir_path}")
            # Skip checking files inside the directory if the directory itself is missing
            continue
        
        # Check if all expected files exist in the current directory
        for file in expected_files:
            # Construct the full path to the file
            file_path = os.path.join(dir_path, file)
            # If the file does not exist, record it as missing
            if not os.path.exists(file_path):
                missing_items.append(f"Missing file or directory: {file_path}")
    
    # If any missing items were found, raise a custom error with the list of missing items
    if missing_items:
        raise DirectoryStructureError(missing_items)
    else:
        # If all directories and files are present, print a success message
        print("Directory structure matches the expected structure.")

# %%
def startHBsearch(pdb_path, hb_file, pse_file, solvent_key, connections):
    '''
    Function to initiate an HB search using a specific PDB file, hydrogen bond definition, solvent key, 
    and connection settings for the hb-search command. This function dynamically sets the environment 
    and selects the appropriate executable based on the operating system.
    
    :param pdb_path: Path to the PDB file to be processed.
    :param hb_file: Hydrogen bond definition file.
    :param pse_file: PSE file (periodic table information).
    :param solvent_key: Solvent key to define solvent atoms.
    :param connections: Connection file for HB search.
    :return: Output of the hb-search subprocess.
    '''
    
    # Setting environment variable
    os.environ['PSE_FILE'] = 'period-table-info.txt'
    
    # Determine operating system
    osys = platform.system()
    
    try:
        # Executing hb_search
        hbs = subprocess.run(
            os.path.normpath(f"./{osys}/hb-search -hb {hb_file} -solv {solvent_key} -con {connections} {pdb_path}"),
            capture_output=True, shell=True, check=True, text=True
        ).stdout
    
    except subprocess.CalledProcessError as e:
        # Raise custom error for hb-search failure
        raise SubprocessError(f"HB-search execution failed with error: {e}", e.output)
    
    return hbs

# %%
def readInHBS(pdb_id, hbs):
    '''
    Function to process the output of an HB search, extracting relevant information for hydrogen bonds.
    The function splits the HB search output, filters for rows indicating hydrogen bonds (HBOND), 
    and applies transformations to format and identify donor/acceptor atoms.

    :param pdb_id: The PDB ID of the structure being analyzed.
    :param hbs: The HB search result string containing hydrogen bond information.
    :return: A pandas DataFrame containing formatted acceptor and donor data along with their IDs.
    '''
    try:
        # Split the file into rows and split each row into columns
        hbs_data = [line.split() for line in hbs.strip().split('\n') if line.strip()]

        # Define the column headers
        headers = ['IDENT', 'ACC', 'sep1', 'DONO', ':', 'x', 'y', 'z', 'sep2', 'a', 'b']

        # Create a DataFrame, filter rows where IDENT is "HBOND", and select relevant columns
        df = pd.DataFrame(hbs_data, columns=headers)
        df = df[df['IDENT'] == 'HBOND'][['ACC', 'DONO']]

        # Apply transformations using form4cmd and formID
        df['ACC'] = df['ACC'].apply(lambda x: form4cmd(pdb_id, x))
        df['DONO'] = df['DONO'].apply(lambda x: form4cmd(pdb_id, x))

        df['ACC_ID'] = df['ACC'].apply(lambda x: formID(pdb_id, x))
        df['DONO_ID'] = df['DONO'].apply(lambda x: formID(pdb_id, x))

        return df

    except Exception as e:
        raise ValueError(f"Error processing HBS file: {e}")

# %%
def check_PDB(PDBstr: str, save_loc):
    '''
    Function to check if the given PDB string is a file path or a PDB ID and handle accordingly.
    If it's a file path, the function loads the file into PyMOL and returns the PDB ID.
    If it's a 4-character PDB ID, it fetches the structure from an external source.
    
    :param PDBstr: The PDB file path or PDB ID to be checked.
    :param save_loc: The directory path where the PDB file will be saved if fetched.
    :return: A tuple containing the PDB ID and the file path.
    '''
   
    # Check if input is a file path
    # Check if the input is a file path (by checking if it's a valid file path with a .pdb or .cif extension)
    if os.path.isfile(PDBstr) and PDBstr.lower().endswith(('.pdb', '.cif')):
        if not os.path.exists(PDBstr):
            raise PDBFileNotFoundError(PDBstr)
        # Load the PDB file and extract PDB ID
        cmd.load(PDBstr)
        PDB_ID = os.path.basename(os.path.normpath(PDBstr)).split('.')[0]
        return PDB_ID, PDBstr

    # Check if PDB object is already loaded in PyMOL
    if PDBstr in cmd.get_object_list('all'):
        save_loc = os.path.join(save_loc, PDBstr + '.pdb')
        cmd.save(save_loc)
        return PDBstr, save_loc

    # Handle 4-character numeric PDB IDs
    elif len(PDBstr) == 4 and PDBstr[0].isnumeric():
        # Fetch the PDB ID from an external source
        with contextlib.chdir(save_loc):
            if cmd.fetch(PDBstr) == -1:
                raise PDBFetchError(PDBstr)
        save_loc = os.path.join(save_loc, PDBstr + '.pdb')
        cmd.save(save_loc)
        return PDBstr, save_loc

    # Raise an error for invalid PDB IDs
    else:
        raise InvalidPDBIDError(PDBstr)

# %%
def generate_bond_names(df, pdbID, incr):
    '''
    Function to generate unique bond names and distance commands for each hydrogen bond in the dataframe.
    
    :param df: DataFrame containing hydrogen bond data.
    :param pdbID: PDB ID of the structure being processed.
    :param incr: Incremental number to ensure unique naming.
    :return: DataFrame with bond names and distance commands.
    '''
    df['bond_name'] = df['ACC_ID'] + '-' + df['DONO_ID']  + '_' + str(pdbID) + '_' + str(incr)
    df['distance_cmd'] = 'distance ' + df['bond_name'] + ', ' + df['ACC'] + ', ' + df['DONO']
    return df

def execute_distance_commands(df):
    '''
    Function to execute distance commands in PyMOL for visualizing hydrogen bonds.
    
    :param df: DataFrame containing the distance commands to be executed.
    '''
    cmd.do(';\n'.join(df['distance_cmd'].tolist()))

def create_selections(df):
    '''
    Function to create PyMOL selections for donor and acceptor atoms involved in hydrogen bonds.
    
    :param df: DataFrame containing hydrogen bond data with ACC and DONO columns.
    :return: DataFrame with new columns for donor and acceptor selections.
    '''
    df['dono_sel'] = df['DONO'].str.split('/').str[:5].str.join('/')
    df['acc_sel'] = df['ACC'].str.split('/').str[:5].str.join('/')
    return df

def visualize_selections(df):
    '''
    Function to visualize donor and acceptor atom selections in PyMOL and then delete them to avoid clutter.
    
    :param df: DataFrame containing the donor and acceptor selections.
    '''
    acc_selection = ' + '.join(df['acc_sel'].tolist())
    dono_selection = ' + '.join(df['dono_sel'].tolist())
    
    cmd.select('all_acceptors', acc_selection)
    cmd.delete('all_acceptors')

    cmd.select('all_donors', dono_selection)
    cmd.delete('all_donors')

def group_and_finalize(df, pdbID, incr):
    '''
    Function to group hydrogen bonds and finalize their visualization in PyMOL.
    
    :param df: DataFrame containing bond names and selection data.
    :param pdbID: PDB ID of the structure being processed.
    :param incr: Incremental number to ensure unique naming for groups.
    :return: Tuple containing the list of bond names, the incremented PDB ID, and the final group name.
    '''
    cmd.group(f"HBonds_{pdbID}_{incr}", " ".join(df['bond_name'].tolist()))
    cmd.hide("labels", f"HBonds_{pdbID}_{incr}")
    
    cmd.group(f'HB_{pdbID}_{incr}', pdbID)
    cmd.group(f'HB_{pdbID}_{incr}', f"HBonds_{pdbID}_{incr}")

    cmd.set_name(pdbID, f'{pdbID}_{incr}')
    
    return df['bond_name'].tolist(), f'{pdbID}_{incr}', f'HB_{pdbID}_{incr}'

# Main function
def pymolDisplay(df, pdbID):
    '''
    Main function to display hydrogen bonds in PyMOL. It generates bond names, executes distance commands, 
    creates selections, visualizes them, and finalizes groupings.

    :param df: DataFrame containing hydrogen bond data.
    :param pdbID: PDB ID of the structure being visualized.
    :return: Group information for the hydrogen bond visualization in PyMOL.
    '''
    group_date = get_date().replace('-','')[4:]
    incr = 1

    while f'{pdbID}_{str(incr)}' in cmd.get_names("objects"):
        incr += 1
    
    # Generate bond names
    df = generate_bond_names(df, pdbID, incr)
    
    # Execute distance commands
    execute_distance_commands(df)
    
    # Create selections for acceptors and donors
    df = create_selections(df)
    
    # Visualize the selections
    visualize_selections(df)
    
    # Group and finalize
    return group_and_finalize(df, pdbID, incr)

# %%
#SCRPT_PATH = os.path.dirname(os.path.abspath(__file__))
SCRPT_PATH = '/home/juk/hbond/hbonds_search_pymol'
# info_dct = {}
    
def hbsearch(PDBstr: str,
         info_class,
         pdb_save_loc:str=None,
         hb_file: str = os.path.join(SCRPT_PATH, "hb-define.txt"), 
         pse_file:str = os.path.join(SCRPT_PATH, "period-table-info.txt"),
         solvent_key:str = "NONE",
         connections: str = "0"):
    '''
    Executing hb_search with set parameters and extracting HBOND entries from the output. 
    The function also checks for the presence of the PDB file and manages saving locations for the results.
    
    :param PDBstr: The PDB file path or PDB ID to be processed.
    :param info_class: An instance of a class used to update information such as HBond results.
    :param pdb_save_loc: Directory path where the PDB file should be saved if fetched.
    :param hb_file: Path to the hydrogen bond definition file.
    :param pse_file: Path to the periodic table info file.
    :param solvent_key: Solvent key for hydrogen bond identification.
    :param connections: Connection settings for HB search.
    :return: A dataframe containing hydrogen bond entries from the hb_search output.
    '''
    
    script_path = os.path.abspath('')

    check_directory(script_path)

    if pdb_save_loc is None: 
        pdb_save_loc = os.path.join(script_path, 'pdb_files/')

    # Check if PDB string is fetchable by pymol, already in pymol session, or available if a custom path was provided
    PDB_ID, pdb_path = check_PDB(PDBstr, pdb_save_loc)

    # Run HBsearch
    hb_save_loc = os.path.join(script_path, 'hb_results', PDB_ID + '_' + get_date())
    os.mkdir(hb_save_loc)
    
    hbs = startHBsearch(pdb_path, hb_file, pse_file, solvent_key, connections)

    with contextlib.chdir(hb_save_loc):
        with open(f'{PDB_ID}.hb', 'w') as file:
            # Write the content string to the file
            file.write(hbs)
    
    df = readInHBS(PDB_ID, hbs)

    bondlist, newPDBid, group_name = pymolDisplay(df, PDB_ID)

    info_class.update_dict(    
        {newPDBid : {
            "hb_save_loc" : hb_save_loc,
            "hb_file_name": f'{PDB_ID}.hb',
            "group_name"  : group_name
            }
        }
    )

# %% [markdown]
# # HB Network

# %%
def exec_hbnet(mol: str):
    '''
    Function to execute the hb-network program for a specified molecule. 
    This function checks whether the hb-search has been performed for the molecule, 
    retrieves the corresponding hydrogen bond file, and runs the hb-network command.
    
    :param mol: The molecule identifier (PDB ID or structure name) for which the hb-network should be executed.
    :return: The output from the hb-network command.
    '''
    info_dct = info_class.get_dict()

    if not mol in info_dct.keys():
        raise PipelineError(f"No hb-file found for {mol}. Make sure hbsearch was executed for the respective molecule")

    # Determine operating system
    osys = platform.system()
    
    hbfile_path = os.path.join(info_dct[mol]['hb_save_loc'], info_dct[mol]['hb_file_name'])
    info_class.update_dict(info_dct)
    
    try:
        # Executing hb_network
        with contextlib.chdir(info_dct[mol]['hb_save_loc']):
            hbn = subprocess.run(
                os.path.normpath(f"{SCRPT_PATH}/{osys}/hb-network {hbfile_path}"),
                    capture_output=True, shell=True, check=True, text=True
            ).stdout
    
    except subprocess.CalledProcessError as e:
        # Raise custom error for hb-network failure
        raise SubprocessError(f"HB-network execution failed with error: {e}", e.output)

    return hbn

# %%
def eval_cluster(mol: str):
    '''
    Function to evaluate and process cluster files for a given molecule. 
    It reads the cluster files, transforms the donor and acceptor information, 
    and stores the processed data in a dictionary, which is then updated in the info_class.
    
    :param mol: The molecule identifier (PDB ID or structure name) for which clusters are being evaluated.
    :return: None (updates the info_class with cluster information).
    '''
    
    info_dct = info_class.get_dict()
    directory = info_dct[mol]['hb_save_loc'] + '/CLUSTER'
    file_dict = {}
    headers = ['SPEC', 'ACC', 'SEP', 'DONO']
    
    # Loop through all files in the directory
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        
        # Check if it is a file
        if os.path.isfile(file_path):
            # Check if the file has size 0 and delete if so
            if os.path.getsize(file_path) == 0:
                os.remove(file_path)
                print(f"Deleted empty file: {filename}")
            else:
                with open(file_path, 'r') as file: 
                    for_df = [line.split() for line in file.read().strip().split('\n') if line.strip()]
                    df = pd.DataFrame(for_df, columns=headers)
        
                    # Apply transformations using form4cmd and formID
                    df['ACC'] = df['ACC'].apply(lambda x: form4cmd(mol, x))
                    df['DONO'] = df['DONO'].apply(lambda x: form4cmd(mol, x))
            
                    df['ACC_ID'] = df['ACC'].apply(lambda x: formID(mol, x))
                    df['DONO_ID'] = df['DONO'].apply(lambda x: formID(mol, x))
                    file_dict[filename.split('.')[0]] = df
    
    info_dct[mol]['CLUSTERS'] = file_dict
    info_class.update_dict(info_dct)

# %%
def generate_bond_names_and_commands(df, mol, clus_num):
    '''
    Function to generate bond names and distance commands for a cluster.
    
    :param df: DataFrame containing hydrogen bond information.
    :param mol: The molecule identifier.
    :param clus_num: The cluster number.
    :return: Updated DataFrame with bond_name and distance_cmd columns.
    '''
    df['bond_name'] = df['ACC_ID'] + '-' + df['DONO_ID'] + f'_clus-{clus_num}_{mol}'
    df['distance_cmd'] = 'distance ' + df['bond_name'] + ', ' + df['ACC'] + ', ' + df['DONO']
    return df

def execute_distance_commands(df):
    '''
    Function to execute distance commands in PyMOL.
    
    :param df: DataFrame containing distance commands.
    '''
    distance_commands = ';\n'.join(df['distance_cmd'].tolist())
    cmd.do(distance_commands)

def generate_selections(df):
    '''
    Function to generate donor and acceptor selections for PyMOL visualization.
    
    :param df: DataFrame containing hydrogen bond information.
    :return: Tuple of acceptor and donor selections.
    '''
    df['dono_sel'] = df['DONO'].str.split('/').str[:5].str.join('/')
    df['acc_sel'] = df['ACC'].str.split('/').str[:5].str.join('/')
    acc_selection = ' + '.join(df['acc_sel'].tolist())
    dono_selection = ' + '.join(df['dono_sel'].tolist())
    return acc_selection, dono_selection

def execute_pymol_commands(cluster_name, acc_selection, dono_selection, df, mol, group_name, color):
    '''
    Function to execute PyMOL commands for visualizing and grouping clusters.
    
    :param cluster_name: Name of the cluster.
    :param acc_selection: Acceptor selection command.
    :param dono_selection: Donor selection command.
    :param df: DataFrame containing bond names.
    :param mol: The molecule identifier.
    :param group_name: The name of the group in PyMOL.
    :param color: The color to apply to the cluster.
    '''
    pymol_commands = [
        f'select all_acceptors, {acc_selection}',
        'show sticks, all_acceptors',
        f'color {color}, all_acceptors',
        'delete all_acceptors',
        f'select all_donors, {dono_selection}',
        'show sticks, all_donors',
        f'color {color}, all_donors',
        'delete all_donors',
        f'group {cluster_name}, {" ".join(df["bond_name"].tolist())}',
        f'hide labels, {cluster_name}',
        f'color {color}, {cluster_name}',
        f'group Clusters_{mol}, {cluster_name}',
        f'group {group_name}, Clusters_{mol}'
    ]
    cmd.do(';\n'.join(pymol_commands))

def pymol_clusters(mol: str, clus_size:int):
    '''
    Function to visualize hydrogen bond clusters in PyMOL for a given molecule.
    
    :param mol: The molecule identifier (PDB ID or structure name).
    '''
    info_dct = info_class.get_dict()
    clusters = info_dct[mol]['CLUSTERS']
    group_name = info_dct[mol]['group_name']

    # Define a color scheme
    colors = ['red', 'blue', 'yellow', 'cyan', 'orange', 'purple', 'teal', 'brown', 'lime', 'grey']
    color_index = 0

    # Process each cluster
    for key, df in clusters.items():
        cluster_name = f'{key}_{mol}'
        # if key == 'cluster-12':
        #     break
        clus_num = key.split('-')[1]

        # Generate bond names and distance commands
        df = generate_bond_names_and_commands(df, mol, clus_num)
        cmp = len( list( set( df.ACC.values.tolist() + df.DONO.values.tolist() ) ) )

        # Continue if the unique number of cluster atoms is too small
        if cmp and clus_size and cmp < clus_size: 
            print(f'Number of unique atoms in {cluster_name} smaller than cutoff( {clus_size} ). Skipped! ')
            continue
            
        # Execute distance commands in PyMOL
        execute_distance_commands(df)

        # Generate acceptor and donor selections
        acc_selection, dono_selection = generate_selections(df)

        # Get the color for this cluster, cycle if there are more clusters than colors
        color = colors[color_index % len(colors)]
        color_index += 1

        # Execute batch PyMOL commands for visualization, grouping, and coloring
        execute_pymol_commands(cluster_name, acc_selection, dono_selection, df, mol, group_name, color)

# %%
def format_selection(selection_str):
    '''
    Function to format a PyMOL selection string into a truncated form for cross-checking with a DataFrame.
    
    :param selection_str: PyMOL selection string (e.g., /4akr_1/A/A/SER`3/OG or /4akr_1/A/A/3/OG).
    :return: Tuple containing the PDB object and the formatted string as '/pdb_object//chain/resi_number/atom_name'.
    :raises ValueError: If the selection string format is invalid.
    '''
    
    # Split the selection string by '/'
    parts = selection_str.split('/')
    
    # Extract the necessary components from the selection string
    try:
        pdb_object = parts[1]  # The PDB object, e.g., 4akr_1
        chain = parts[2]  # Chain identifier, e.g., A
        
        # Handle cases where the chain may be missing
        if not chain:
            chain = parts[3]
        
        resi_part = parts[4]  # Residue part, could be SER`3 or just 3
        atom_name = parts[5]  # Atom identifier, e.g., OG
        
        # Check if the residue part contains a backtick (`), which separates residue name and number
        if '`' in resi_part:
            # Split residue part into residue name and residue number (e.g., SER`3 -> 3)
            resi_number = resi_part.split('`')[1]
        else:
            # If there's no backtick, assume it's already a residue number
            resi_number = resi_part
        
        # Format the string as '/pdb_object//chain/resi_number/atom_name'
        formatted_str = f"/{pdb_object}//{chain}/{resi_number}/{atom_name}"
        
        return pdb_object, formatted_str
    
    except IndexError:
        raise ValueError(f"Invalid selection string format: {selection_str}")

# %%
def flatten(lst):
    '''
    Function to flatten a list of lists into a single list.
    
    :param lst: List of lists to be flattened.
    :return: A flattened list containing all elements from the sublists.
    '''
    return [item for sublst in lst for item in sublst]

def select_atoms_from_list(atom_list, selection_name="selected_atoms"):
    '''
    Function to create a PyMOL selection from a list of atom selection strings.
    
    :param atom_list: A list of PyMOL atom selections (e.g., ['/4akr_1//A/6/OE1', ...]).
    :param selection_name: The name of the new selection in PyMOL (default is 'selected_atoms').
    :return: The name of the created selection.
    '''
    
    # Join all the selections in the list using 'or' operator for PyMOL
    combined_selection = " or ".join(atom_list)
    
    # Use cmd.select to create a new selection
    cmd.select(selection_name, combined_selection)
    cmd.zoom(selection_name, 4)
    print(f"Selection '{selection_name}' created with atoms: {atom_list}")
    
    return selection_name

def shownet(sel_str):
    '''
    Function to show the hydrogen bond network related to the selected atom in PyMOL.
    
    :param sel_str: PyMOL selection string (e.g., '/4akr_1//A/6/OE1').
    :return: Tuple containing the PDB object and the formatted selection string.
    :raises InvalidSelectionError: If the selection string is invalid or no atom is found.
    '''
    
    # Check if there is an object (characters) between the first and second slash
    parts = selection.split('/')
    
    if len(parts) < 3 or not parts[1]:
        raise InvalidSelectionError(f'Invalid selection string format: {sel_str}. Please define underlying PDB after first slash.')
    
    model = cmd.get_model(sel_str)
    
    # Check if the model contains any atoms
    if not model['atom']:
        raise InvalidSelectionError(f'No atom present according to selection string: {sel_str}')
    
    elif len(model['atom']) > 1:
        raise InvalidSelectionError(f'More than one atom selected with: {sel_str}. Please pass string providing single selection')

    # Format the selection string and retrieve the PDB object
    pdb_obj, frm_str = format_selection(sel_str)
    
    sel_lst = []
    info_dct = info_class.get_dict()
    
    # Check if the atom is part of any hydrogen bond network
    for clust_num, df in info_dct[pdb_obj]['CLUSTERS'].items():
        acc_lst = df.ACC.values.tolist()
        dono_lst = df.DONO.values.tolist()
        if frm_str in acc_lst or frm_str in dono_lst:
            sel_lst.append(acc_lst + dono_lst)
    
    # Flatten the list and remove duplicates
    sel_lst = list(set(flatten(sel_lst)))

    # Raise an error if the selection is not part of any hydrogen bond network
    if not sel_lst:
        raise InvalidSelectionError(f"{sel_str} is not part of a hydrogen bond network.")
    
    # Select atoms from the list in PyMOL
    select_atoms_from_list(sel_lst)
    
    return pdb_obj, frm_str

# %%
def hbnet(mol: str, clus_size: int = None):
    '''
    Function to execute the hydrogen bond network analysis and visualize the results in PyMOL.
    
    :param mol: The molecule identifier (e.g., PDB ID or structure name).
    :param clus_size: Optional parameter to specify the cluster size (default is None).
    :return: None
    '''
    hbn = exec_hbnet(mol)  # Execute the hydrogen bond network analysis for the molecule
    eval_cluster(mol)  # Evaluate and process the clusters for the molecule
    pymol_clusters(mol, clus_size)  # Visualize the clusters in PyMOL

# %%
cmd.extend("hbsearch", hbsearch)
cmd.extend("hbnet", hbnet)
cmd.extend("shownet", shownet)
# Out:
# <function __main__.shownet(sel_str)>

# %%
hbsearch
# Out:
# <function __main__.hbsearch(PDBstr: str, info_class, pdb_save_loc: str = None, hb_file: str = '/home/juk/hbond/hbonds_search_pymol/hb-define.txt', pse_file: str = '/home/juk/hbond/hbonds_search_pymol/period-table-info.txt', solvent_key: str = 'NONE', connections: str = '0')>

# %%
mol = '4akr_1'

# %%
cmd.reinitialize()
# Example usage
info_class = DictionaryManager()

cmd = xmlrpclib.ServerProxy('http://localhost:9123')
hbsearch('4akr', info_class)
# Out:
# Directory structure matches the expected structure.

# %%
hbnet('4akr_1')
# Out:
# Deleted empty file: cluster-2.hb-ntw
# Deleted empty file: cluster-3.hb-ntw
# Deleted empty file: cluster-4.hb-ntw
# Deleted empty file: cluster-5.hb-ntw
# Deleted empty file: cluster-6.hb-ntw
# Deleted empty file: cluster-7.hb-ntw
# Deleted empty file: cluster-9.hb-ntw
# Deleted empty file: cluster-10.hb-ntw
# Deleted empty file: cluster-11.hb-ntw
# Deleted empty file: cluster-13.hb-ntw
# Deleted empty file: cluster-16.hb-ntw
# Deleted empty file: cluster-17.hb-ntw
# Deleted empty file: cluster-18.hb-ntw
# Deleted empty file: cluster-21.hb-ntw
# Deleted empty file: cluster-23.hb-ntw
# Deleted empty file: cluster-24.hb-ntw
# Deleted empty file: cluster-25.hb-ntw
# Deleted empty file: cluster-26.hb-ntw
# Deleted empty file: cluster-27.hb-ntw
# Deleted empty file: cluster-28.hb-ntw
# Deleted empty file: cluster-29.hb-ntw
# Deleted empty file: cluster-31.hb-ntw
# Deleted empty file: cluster-35.hb-ntw
# Deleted empty file: cluster-36.hb-ntw
# Deleted empty file: cluster-37.hb-ntw
# Deleted empty file: cluster-43.hb-ntw
# Deleted empty file: cluster-44.hb-ntw
# Deleted empty file: cluster-45.hb-ntw
# Deleted empty file: cluster-47.hb-ntw
# Deleted empty file: cluster-50.hb-ntw
# Deleted empty file: cluster-51.hb-ntw
# Deleted empty file: cluster-52.hb-ntw
# Deleted empty file: cluster-53.hb-ntw
# Deleted empty file: cluster-55.hb-ntw
# Deleted empty file: cluster-56.hb-ntw
# Deleted empty file: cluster-57.hb-ntw
# Deleted empty file: cluster-58.hb-ntw
# Deleted empty file: cluster-60.hb-ntw
# Deleted empty file: cluster-63.hb-ntw
# Deleted empty file: cluster-70.hb-ntw
# Deleted empty file: cluster-73.hb-ntw
# Deleted empty file: cluster-77.hb-ntw
# Deleted empty file: cluster-78.hb-ntw
# Deleted empty file: cluster-79.hb-ntw
# Deleted empty file: cluster-80.hb-ntw
# Deleted empty file: cluster-81.hb-ntw
# Deleted empty file: cluster-82.hb-ntw
# Deleted empty file: cluster-83.hb-ntw
# Deleted empty file: cluster-84.hb-ntw
# Deleted empty file: cluster-85.hb-ntw
# Deleted empty file: cluster-86.hb-ntw
# Deleted empty file: cluster-87.hb-ntw
# Deleted empty file: cluster-88.hb-ntw
# Deleted empty file: cluster-90.hb-ntw
# Deleted empty file: cluster-91.hb-ntw
# Deleted empty file: cluster-92.hb-ntw
# Deleted empty file: cluster-93.hb-ntw
# Deleted empty file: cluster-94.hb-ntw
# Deleted empty file: cluster-99.hb-ntw
# Deleted empty file: cluster-100.hb-ntw
# Deleted empty file: cluster-101.hb-ntw
# Deleted empty file: cluster-102.hb-ntw
# Deleted empty file: cluster-105.hb-ntw
# Deleted empty file: cluster-106.hb-ntw
# Deleted empty file: cluster-108.hb-ntw
# Deleted empty file: cluster-110.hb-ntw
# Deleted empty file: cluster-111.hb-ntw
# Deleted empty file: cluster-112.hb-ntw
# Deleted empty file: cluster-116.hb-ntw
# Deleted empty file: cluster-118.hb-ntw
# Deleted empty file: cluster-120.hb-ntw
# Deleted empty file: cluster-121.hb-ntw
# Deleted empty file: cluster-122.hb-ntw
# Deleted empty file: cluster-124.hb-ntw
# Deleted empty file: cluster-125.hb-ntw
# Deleted empty file: cluster-126.hb-ntw
# Deleted empty file: cluster-127.hb-ntw
# Deleted empty file: cluster-128.hb-ntw
# Deleted empty file: cluster-129.hb-ntw
# Deleted empty file: cluster-130.hb-ntw
# Deleted empty file: cluster-133.hb-ntw
# Deleted empty file: cluster-134.hb-ntw
# Deleted empty file: cluster-135.hb-ntw
# Deleted empty file: cluster-136.hb-ntw
# Deleted empty file: cluster-138.hb-ntw
# Deleted empty file: cluster-140.hb-ntw
# Deleted empty file: cluster-141.hb-ntw
# Deleted empty file: cluster-142.hb-ntw
# Deleted empty file: cluster-143.hb-ntw
# Deleted empty file: cluster-145.hb-ntw
# Deleted empty file: cluster-147.hb-ntw
# Deleted empty file: cluster-148.hb-ntw
# Deleted empty file: cluster-150.hb-ntw
# Deleted empty file: cluster-151.hb-ntw
# Deleted empty file: cluster-152.hb-ntw
# Deleted empty file: cluster-153.hb-ntw
# Deleted empty file: cluster-154.hb-ntw
# Deleted empty file: cluster-155.hb-ntw
# Deleted empty file: cluster-156.hb-ntw
# Deleted empty file: cluster-157.hb-ntw
# Deleted empty file: cluster-158.hb-ntw
# Deleted empty file: cluster-159.hb-ntw
# Deleted empty file: cluster-162.hb-ntw
# Deleted empty file: cluster-163.hb-ntw
# Deleted empty file: cluster-165.hb-ntw
# Deleted empty file: cluster-166.hb-ntw
# Deleted empty file: cluster-167.hb-ntw
# Deleted empty file: cluster-168.hb-ntw
# Deleted empty file: cluster-169.hb-ntw
# Deleted empty file: cluster-170.hb-ntw
# Deleted empty file: cluster-171.hb-ntw
# Deleted empty file: cluster-172.hb-ntw
# Deleted empty file: cluster-173.hb-ntw
# Deleted empty file: cluster-174.hb-ntw
# Deleted empty file: cluster-175.hb-ntw
# Deleted empty file: cluster-176.hb-ntw
# Deleted empty file: cluster-178.hb-ntw
# Deleted empty file: cluster-179.hb-ntw
# Deleted empty file: cluster-180.hb-ntw
# Deleted empty file: cluster-182.hb-ntw
# Deleted empty file: cluster-183.hb-ntw
# Deleted empty file: cluster-184.hb-ntw
# Deleted empty file: cluster-185.hb-ntw
# Deleted empty file: cluster-186.hb-ntw
# Deleted empty file: cluster-187.hb-ntw
# Deleted empty file: cluster-188.hb-ntw
# Deleted empty file: cluster-190.hb-ntw
# Deleted empty file: cluster-193.hb-ntw
# Deleted empty file: cluster-194.hb-ntw
# Deleted empty file: cluster-195.hb-ntw
# Deleted empty file: cluster-197.hb-ntw
# Deleted empty file: cluster-199.hb-ntw
# Deleted empty file: cluster-204.hb-ntw
# Deleted empty file: cluster-206.hb-ntw
# Deleted empty file: cluster-207.hb-ntw
# Deleted empty file: cluster-208.hb-ntw
# Deleted empty file: cluster-209.hb-ntw
# Deleted empty file: cluster-210.hb-ntw
# Deleted empty file: cluster-211.hb-ntw
# Deleted empty file: cluster-213.hb-ntw
# Deleted empty file: cluster-215.hb-ntw
# Deleted empty file: cluster-217.hb-ntw
# Deleted empty file: cluster-218.hb-ntw
# Deleted empty file: cluster-219.hb-ntw
# Deleted empty file: cluster-222.hb-ntw
# Deleted empty file: cluster-225.hb-ntw
# Deleted empty file: cluster-226.hb-ntw
# Deleted empty file: cluster-227.hb-ntw
# Deleted empty file: cluster-228.hb-ntw
# Deleted empty file: cluster-230.hb-ntw
# Deleted empty file: cluster-231.hb-ntw
# Deleted empty file: cluster-232.hb-ntw
# Deleted empty file: cluster-233.hb-ntw
# Deleted empty file: cluster-234.hb-ntw
# Deleted empty file: cluster-235.hb-ntw
# Deleted empty file: cluster-236.hb-ntw
# Deleted empty file: cluster-238.hb-ntw
# Deleted empty file: cluster-239.hb-ntw
# Deleted empty file: cluster-240.hb-ntw
# Deleted empty file: cluster-242.hb-ntw
# Deleted empty file: cluster-243.hb-ntw
# Deleted empty file: cluster-244.hb-ntw
# Deleted empty file: cluster-245.hb-ntw
# Deleted empty file: cluster-246.hb-ntw
# Deleted empty file: cluster-247.hb-ntw
# Deleted empty file: cluster-249.hb-ntw
# Deleted empty file: cluster-250.hb-ntw
# Deleted empty file: cluster-251.hb-ntw
# Deleted empty file: cluster-252.hb-ntw
# Deleted empty file: cluster-253.hb-ntw
# Deleted empty file: cluster-254.hb-ntw
# Deleted empty file: cluster-255.hb-ntw
# Deleted empty file: cluster-256.hb-ntw
# Deleted empty file: cluster-257.hb-ntw
# Deleted empty file: cluster-258.hb-ntw
# Deleted empty file: cluster-260.hb-ntw
# Deleted empty file: cluster-262.hb-ntw
# Deleted empty file: cluster-263.hb-ntw
# Deleted empty file: cluster-264.hb-ntw
# Deleted empty file: cluster-265.hb-ntw
# Deleted empty file: cluster-266.hb-ntw
# Deleted empty file: cluster-267.hb-ntw
# Deleted empty file: cluster-268.hb-ntw
# Deleted empty file: cluster-269.hb-ntw
# Deleted empty file: cluster-271.hb-ntw
# Deleted empty file: cluster-273.hb-ntw
# Deleted empty file: cluster-274.hb-ntw
# Deleted empty file: cluster-275.hb-ntw
# Deleted empty file: cluster-277.hb-ntw
# Deleted empty file: cluster-278.hb-ntw
# Deleted empty file: cluster-279.hb-ntw
# Deleted empty file: cluster-280.hb-ntw
# Deleted empty file: cluster-281.hb-ntw
# Deleted empty file: cluster-282.hb-ntw
# Deleted empty file: cluster-284.hb-ntw
# Deleted empty file: cluster-285.hb-ntw
# Deleted empty file: cluster-286.hb-ntw
# Deleted empty file: cluster-287.hb-ntw
# Deleted empty file: cluster-288.hb-ntw
# Deleted empty file: cluster-289.hb-ntw
# Deleted empty file: cluster-291.hb-ntw
# Deleted empty file: cluster-292.hb-ntw
# Deleted empty file: cluster-293.hb-ntw
# Deleted empty file: cluster-294.hb-ntw
# Deleted empty file: cluster-295.hb-ntw
# Deleted empty file: cluster-296.hb-ntw
# Deleted empty file: cluster-297.hb-ntw
# Deleted empty file: cluster-298.hb-ntw
# Deleted empty file: cluster-299.hb-ntw
# Deleted empty file: cluster-300.hb-ntw
# Deleted empty file: cluster-301.hb-ntw
# Deleted empty file: cluster-302.hb-ntw
# Deleted empty file: cluster-303.hb-ntw
# Deleted empty file: cluster-304.hb-ntw
# Deleted empty file: cluster-305.hb-ntw
# Deleted empty file: cluster-306.hb-ntw
# Deleted empty file: cluster-307.hb-ntw
# Deleted empty file: cluster-308.hb-ntw
# Deleted empty file: cluster-309.hb-ntw
# Deleted empty file: cluster-310.hb-ntw
# Deleted empty file: cluster-311.hb-ntw
# Deleted empty file: cluster-312.hb-ntw
# Deleted empty file: cluster-313.hb-ntw
# Deleted empty file: cluster-315.hb-ntw
# Deleted empty file: cluster-316.hb-ntw
# Deleted empty file: cluster-317.hb-ntw
# Deleted empty file: cluster-319.hb-ntw
# Deleted empty file: cluster-321.hb-ntw
# Deleted empty file: cluster-322.hb-ntw
# Deleted empty file: cluster-323.hb-ntw
# Deleted empty file: cluster-325.hb-ntw
# Deleted empty file: cluster-326.hb-ntw
# Deleted empty file: cluster-327.hb-ntw
# Deleted empty file: cluster-332.hb-ntw
# Deleted empty file: cluster-333.hb-ntw
# Deleted empty file: cluster-334.hb-ntw
# Deleted empty file: cluster-335.hb-ntw
# Deleted empty file: cluster-336.hb-ntw
# Deleted empty file: cluster-337.hb-ntw
# Deleted empty file: cluster-338.hb-ntw
# Deleted empty file: cluster-341.hb-ntw
# Deleted empty file: cluster-344.hb-ntw
# Deleted empty file: cluster-346.hb-ntw
# Deleted empty file: cluster-347.hb-ntw
# Deleted empty file: cluster-349.hb-ntw
# Deleted empty file: cluster-350.hb-ntw
# Deleted empty file: cluster-351.hb-ntw
# Deleted empty file: cluster-353.hb-ntw
# Deleted empty file: cluster-354.hb-ntw
# Deleted empty file: cluster-355.hb-ntw
# Deleted empty file: cluster-356.hb-ntw
# Deleted empty file: cluster-357.hb-ntw
# Deleted empty file: cluster-361.hb-ntw
# Deleted empty file: cluster-366.hb-ntw
# Deleted empty file: cluster-367.hb-ntw
# Deleted empty file: cluster-370.hb-ntw
# Deleted empty file: cluster-371.hb-ntw
# Deleted empty file: cluster-373.hb-ntw
# Deleted empty file: cluster-380.hb-ntw
# Deleted empty file: cluster-381.hb-ntw
# Deleted empty file: cluster-382.hb-ntw
# Deleted empty file: cluster-383.hb-ntw
# Deleted empty file: cluster-384.hb-ntw
# Deleted empty file: cluster-385.hb-ntw
# Deleted empty file: cluster-386.hb-ntw
# Deleted empty file: cluster-387.hb-ntw
# Deleted empty file: cluster-388.hb-ntw
# Deleted empty file: cluster-389.hb-ntw
# Deleted empty file: cluster-390.hb-ntw
# Deleted empty file: cluster-391.hb-ntw
# Deleted empty file: cluster-393.hb-ntw
# Deleted empty file: cluster-394.hb-ntw
# Deleted empty file: cluster-395.hb-ntw
# Deleted empty file: cluster-396.hb-ntw
# Deleted empty file: cluster-397.hb-ntw
# Deleted empty file: cluster-400.hb-ntw
# Deleted empty file: cluster-401.hb-ntw
# Deleted empty file: cluster-402.hb-ntw
# Deleted empty file: cluster-404.hb-ntw
# Deleted empty file: cluster-405.hb-ntw
# Deleted empty file: cluster-409.hb-ntw
# Deleted empty file: cluster-410.hb-ntw
# Deleted empty file: cluster-413.hb-ntw
# Deleted empty file: cluster-415.hb-ntw
# Deleted empty file: cluster-416.hb-ntw
# Deleted empty file: cluster-417.hb-ntw
# Deleted empty file: cluster-418.hb-ntw
# Deleted empty file: cluster-419.hb-ntw
# Deleted empty file: cluster-420.hb-ntw
# Deleted empty file: cluster-421.hb-ntw
# Deleted empty file: cluster-423.hb-ntw
# Deleted empty file: cluster-425.hb-ntw
# Deleted empty file: cluster-427.hb-ntw
# Deleted empty file: cluster-428.hb-ntw
# Deleted empty file: cluster-429.hb-ntw
# Deleted empty file: cluster-430.hb-ntw
# Deleted empty file: cluster-431.hb-ntw
# Deleted empty file: cluster-432.hb-ntw
# Deleted empty file: cluster-434.hb-ntw
# Deleted empty file: cluster-436.hb-ntw
# Deleted empty file: cluster-437.hb-ntw
# Deleted empty file: cluster-438.hb-ntw
# Deleted empty file: cluster-439.hb-ntw
# Deleted empty file: cluster-442.hb-ntw
# Deleted empty file: cluster-444.hb-ntw
# Deleted empty file: cluster-445.hb-ntw
# Deleted empty file: cluster-448.hb-ntw
# Deleted empty file: cluster-449.hb-ntw
# Deleted empty file: cluster-450.hb-ntw
# Deleted empty file: cluster-452.hb-ntw
# Deleted empty file: cluster-453.hb-ntw
# Deleted empty file: cluster-454.hb-ntw
# Deleted empty file: cluster-455.hb-ntw
# Deleted empty file: cluster-456.hb-ntw
# Deleted empty file: cluster-457.hb-ntw
# Deleted empty file: cluster-458.hb-ntw
# Deleted empty file: cluster-459.hb-ntw
# Deleted empty file: cluster-461.hb-ntw
# Deleted empty file: cluster-462.hb-ntw
# Deleted empty file: cluster-465.hb-ntw
# Deleted empty file: cluster-468.hb-ntw
# Deleted empty file: cluster-469.hb-ntw
# Deleted empty file: cluster-470.hb-ntw
# Deleted empty file: cluster-471.hb-ntw
# Deleted empty file: cluster-473.hb-ntw
# Deleted empty file: cluster-474.hb-ntw
# Deleted empty file: cluster-475.hb-ntw
# Deleted empty file: cluster-477.hb-ntw
# Deleted empty file: cluster-479.hb-ntw
# Deleted empty file: cluster-480.hb-ntw
# Deleted empty file: cluster-481.hb-ntw
# Deleted empty file: cluster-483.hb-ntw
# Deleted empty file: cluster-484.hb-ntw
# Deleted empty file: cluster-487.hb-ntw
# Deleted empty file: cluster-488.hb-ntw
# Deleted empty file: cluster-489.hb-ntw
# Deleted empty file: cluster-490.hb-ntw
# Deleted empty file: cluster-491.hb-ntw
# Deleted empty file: cluster-492.hb-ntw
# Deleted empty file: cluster-493.hb-ntw
# Deleted empty file: cluster-495.hb-ntw
# Deleted empty file: cluster-496.hb-ntw
# Deleted empty file: cluster-498.hb-ntw
# Deleted empty file: cluster-501.hb-ntw
# Deleted empty file: cluster-503.hb-ntw
# Deleted empty file: cluster-504.hb-ntw
# Deleted empty file: cluster-505.hb-ntw
# Deleted empty file: cluster-506.hb-ntw
# Deleted empty file: cluster-510.hb-ntw
# Deleted empty file: cluster-511.hb-ntw
# Deleted empty file: cluster-512.hb-ntw
# Deleted empty file: cluster-513.hb-ntw
# Deleted empty file: cluster-514.hb-ntw
# Deleted empty file: cluster-515.hb-ntw
# Deleted empty file: cluster-516.hb-ntw
# Deleted empty file: cluster-520.hb-ntw
# Deleted empty file: cluster-522.hb-ntw
# Deleted empty file: cluster-525.hb-ntw
# Deleted empty file: cluster-526.hb-ntw
# Deleted empty file: cluster-527.hb-ntw
# Deleted empty file: cluster-529.hb-ntw
# Deleted empty file: cluster-530.hb-ntw
# Deleted empty file: cluster-531.hb-ntw
# Deleted empty file: cluster-532.hb-ntw
# Deleted empty file: cluster-533.hb-ntw
# Deleted empty file: cluster-536.hb-ntw
# Deleted empty file: cluster-537.hb-ntw
# Deleted empty file: cluster-539.hb-ntw
# Deleted empty file: cluster-541.hb-ntw
# Deleted empty file: cluster-542.hb-ntw
# Deleted empty file: cluster-544.hb-ntw
# Deleted empty file: cluster-545.hb-ntw
# Deleted empty file: cluster-548.hb-ntw
# Deleted empty file: cluster-552.hb-ntw
# Deleted empty file: cluster-553.hb-ntw
# Deleted empty file: cluster-554.hb-ntw
# Deleted empty file: cluster-556.hb-ntw
# Deleted empty file: cluster-557.hb-ntw
# Deleted empty file: cluster-558.hb-ntw
# Deleted empty file: cluster-559.hb-ntw
# Deleted empty file: cluster-560.hb-ntw
# Deleted empty file: cluster-561.hb-ntw
# Deleted empty file: cluster-562.hb-ntw
# Deleted empty file: cluster-564.hb-ntw
# Deleted empty file: cluster-565.hb-ntw
# Deleted empty file: cluster-566.hb-ntw
# Deleted empty file: cluster-567.hb-ntw
# Deleted empty file: cluster-568.hb-ntw
# Deleted empty file: cluster-569.hb-ntw
# Deleted empty file: cluster-572.hb-ntw
# Deleted empty file: cluster-573.hb-ntw
# Deleted empty file: cluster-574.hb-ntw
# Deleted empty file: cluster-575.hb-ntw
# Deleted empty file: cluster-576.hb-ntw
# Deleted empty file: cluster-577.hb-ntw
# Deleted empty file: cluster-578.hb-ntw
# Deleted empty file: cluster-580.hb-ntw
# Deleted empty file: cluster-581.hb-ntw
# Deleted empty file: cluster-586.hb-ntw
# Deleted empty file: cluster-587.hb-ntw
# Deleted empty file: cluster-588.hb-ntw
# Deleted empty file: cluster-591.hb-ntw
# Deleted empty file: cluster-594.hb-ntw
# Deleted empty file: cluster-595.hb-ntw
# Deleted empty file: cluster-597.hb-ntw
# Deleted empty file: cluster-598.hb-ntw
# Deleted empty file: cluster-599.hb-ntw
# Deleted empty file: cluster-600.hb-ntw
# Deleted empty file: cluster-601.hb-ntw
# Deleted empty file: cluster-602.hb-ntw
# Deleted empty file: cluster-603.hb-ntw
# Deleted empty file: cluster-604.hb-ntw
# Deleted empty file: cluster-606.hb-ntw
# Deleted empty file: cluster-608.hb-ntw
# Deleted empty file: cluster-609.hb-ntw
# Deleted empty file: cluster-610.hb-ntw
# Deleted empty file: cluster-611.hb-ntw
# Deleted empty file: cluster-612.hb-ntw
# Deleted empty file: cluster-613.hb-ntw
# Deleted empty file: cluster-614.hb-ntw
# Deleted empty file: cluster-615.hb-ntw
# Deleted empty file: cluster-617.hb-ntw
# Deleted empty file: cluster-618.hb-ntw
# Deleted empty file: cluster-619.hb-ntw
# Deleted empty file: cluster-620.hb-ntw
# Deleted empty file: cluster-621.hb-ntw
# Deleted empty file: cluster-623.hb-ntw
# Deleted empty file: cluster-624.hb-ntw
# Deleted empty file: cluster-625.hb-ntw
# Deleted empty file: cluster-626.hb-ntw
# Deleted empty file: cluster-628.hb-ntw
# Deleted empty file: cluster-629.hb-ntw
# Deleted empty file: cluster-631.hb-ntw
# Deleted empty file: cluster-633.hb-ntw
# Deleted empty file: cluster-634.hb-ntw
# Deleted empty file: cluster-635.hb-ntw
# Deleted empty file: cluster-636.hb-ntw
# Deleted empty file: cluster-637.hb-ntw
# Deleted empty file: cluster-638.hb-ntw
# Deleted empty file: cluster-639.hb-ntw
# Deleted empty file: cluster-640.hb-ntw
# Deleted empty file: cluster-641.hb-ntw
# Deleted empty file: cluster-642.hb-ntw
# Deleted empty file: cluster-644.hb-ntw
# Deleted empty file: cluster-646.hb-ntw
# Deleted empty file: cluster-647.hb-ntw
# Deleted empty file: cluster-649.hb-ntw
# Deleted empty file: cluster-650.hb-ntw
# Deleted empty file: cluster-651.hb-ntw
# Deleted empty file: cluster-653.hb-ntw
# Deleted empty file: cluster-654.hb-ntw
# Deleted empty file: cluster-655.hb-ntw
# Deleted empty file: cluster-656.hb-ntw
# Deleted empty file: cluster-657.hb-ntw
# Deleted empty file: cluster-658.hb-ntw
# Deleted empty file: cluster-659.hb-ntw
# Deleted empty file: cluster-660.hb-ntw
# Deleted empty file: cluster-661.hb-ntw
# Deleted empty file: cluster-662.hb-ntw
# Deleted empty file: cluster-663.hb-ntw
# Deleted empty file: cluster-664.hb-ntw
# Deleted empty file: cluster-665.hb-ntw
# Deleted empty file: cluster-666.hb-ntw
# Deleted empty file: cluster-667.hb-ntw
# Deleted empty file: cluster-668.hb-ntw
# Deleted empty file: cluster-669.hb-ntw
# Deleted empty file: cluster-670.hb-ntw
# Deleted empty file: cluster-671.hb-ntw
# Deleted empty file: cluster-673.hb-ntw
# Deleted empty file: cluster-674.hb-ntw
# Deleted empty file: cluster-675.hb-ntw
# Deleted empty file: cluster-676.hb-ntw
# Deleted empty file: cluster-677.hb-ntw
# Deleted empty file: cluster-678.hb-ntw
# Deleted empty file: cluster-679.hb-ntw
# Deleted empty file: cluster-680.hb-ntw
# Deleted empty file: cluster-681.hb-ntw
# Deleted empty file: cluster-682.hb-ntw
# Deleted empty file: cluster-683.hb-ntw
# Deleted empty file: cluster-684.hb-ntw
# Deleted empty file: cluster-685.hb-ntw
# Deleted empty file: cluster-686.hb-ntw
# Deleted empty file: cluster-687.hb-ntw
# Deleted empty file: cluster-688.hb-ntw
# Deleted empty file: cluster-689.hb-ntw
# Deleted empty file: cluster-690.hb-ntw
# Deleted empty file: cluster-691.hb-ntw
# Deleted empty file: cluster-692.hb-ntw
# Deleted empty file: cluster-693.hb-ntw
# Deleted empty file: cluster-695.hb-ntw
# Deleted empty file: cluster-696.hb-ntw
# Deleted empty file: cluster-697.hb-ntw
# Deleted empty file: cluster-698.hb-ntw
# Deleted empty file: cluster-699.hb-ntw
# Deleted empty file: cluster-700.hb-ntw
# Deleted empty file: cluster-701.hb-ntw
# Deleted empty file: cluster-702.hb-ntw
# Deleted empty file: cluster-704.hb-ntw
# Deleted empty file: cluster-705.hb-ntw
# Deleted empty file: cluster-706.hb-ntw
# Deleted empty file: cluster-707.hb-ntw
# Deleted empty file: cluster-709.hb-ntw
# Deleted empty file: cluster-710.hb-ntw

# %%
shownet(selection)
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectionError                     Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 shownet(selection)
#
# Cell In[17], line 51, in shownet(sel_str)
#      48     raise InvalidSelectionError(f'No atom present according to selection string: {sel_str}')
#      50 elif len(model['atom']) > 1:
# ---> 51     raise InvalidSelectionError(f'More than one atom selected with: {sel_str}. Please pass string providing single selection')
#      53 # Format the selection string and retrieve the PDB object
#      54 pdb_obj, frm_str = format_selection(sel_str)
#
# InvalidSelectionError: More than one atom selected with: /4akr_1/A/A/ASN`84/. Please pass string providing single selection
